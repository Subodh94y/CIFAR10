# %%
import matplotlib.pyplot as plt
import tensorflow as tf

# Load CIFAR-10 dataset
cifar10 = tf.keras.datasets.cifar10
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# CIFAR-10 class labels
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Function to display images
def plot_images(images, labels):
    plt.figure(figsize=(10, 10))
    for i in range(25):
        plt.subplot(5, 5, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.binary)
        class_index = labels[i][0]
        plt.xlabel(f"{class_names[class_index]} ({class_index})")
    plt.show()

# Display some images from the dataset with labels and class numbers
plot_images(train_images, train_labels)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 11s 0us/step

# %%
import numpy as np

# Count the number of images for each class
class_counts = {class_name: np.sum(train_labels == i) for i, class_name in enumerate(class_names)}

# Print the number of images for each class
for class_name, count in class_counts.items():
    print(f"{class_name}: {count} images")
# Out:
# airplane: 5000 images
# automobile: 5000 images
# bird: 5000 images
# cat: 5000 images
# deer: 5000 images
# dog: 5000 images
# frog: 5000 images
# horse: 5000 images
# ship: 5000 images
# truck: 5000 images

# %%
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler

# Reshape the image data for compatibility with classifiers
train_images_flat = train_images.reshape(train_images.shape[0], -1)
test_images_flat = test_images.reshape(test_images.shape[0], -1)

# Standardize the pixel values
scaler = StandardScaler()
train_images_scaled = scaler.fit_transform(train_images_flat)
test_images_scaled = scaler.transform(test_images_flat)

# Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(train_images_scaled, train_labels.ravel())
rf_predictions = rf_classifier.predict(test_images_scaled)
rf_accuracy = accuracy_score(test_labels, rf_predictions)
print("Random Forest Accuracy:", rf_accuracy)
print("Random Forest Classification Report:")
print(classification_report(test_labels, rf_predictions))

# Logistic Regression classifier
lr_classifier = LogisticRegression(max_iter=1000, random_state=42)
lr_classifier.fit(train_images_scaled, train_labels.ravel())
lr_predictions = lr_classifier.predict(test_images_scaled)
lr_accuracy = accuracy_score(test_labels, lr_predictions)
print("Logistic Regression Accuracy:", lr_accuracy)
print("Logistic Regression Classification Report:")
print(classification_report(test_labels, lr_predictions))

# Decision Tree classifier
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(train_images_scaled, train_labels.ravel())
dt_predictions = dt_classifier.predict(test_images_scaled)
dt_accuracy = accuracy_score(test_labels, dt_predictions)
print("Decision Tree Accuracy:", dt_accuracy)
print("Decision Tree Classification Report:")
print(classification_report(test_labels, dt_predictions))
# Out:
# Random Forest Accuracy: 0.4663
# Random Forest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.56      0.55      1000
#            1       0.52      0.55      0.53      1000
#            2       0.37      0.34      0.35      1000
#            3       0.33      0.28      0.30      1000
#            4       0.39      0.39      0.39      1000
#            5       0.43      0.40      0.41      1000
#            6       0.47      0.56      0.51      1000
#            7       0.50      0.45      0.47      1000
#            8       0.58      0.61      0.59      1000
#            9       0.47      0.53      0.50      1000
#
#     accuracy                           0.47     10000
#    macro avg       0.46      0.47      0.46     10000
# weighted avg       0.46      0.47      0.46     10000
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy: 0.3672
# Logistic Regression Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.41      0.43      0.42      1000
#            1       0.42      0.43      0.43      1000
#            2       0.28      0.26      0.27      1000
#            3       0.24      0.24      0.24      1000
#            4       0.33      0.28      0.30      1000
#            5       0.29      0.30      0.30      1000
#            6       0.39      0.42      0.41      1000
#            7       0.43      0.40      0.41      1000
#            8       0.46      0.51      0.48      1000
#            9       0.40      0.41      0.41      1000
#
#     accuracy                           0.37     10000
#    macro avg       0.37      0.37      0.37     10000
# weighted avg       0.37      0.37      0.37     10000
#
# Decision Tree Accuracy: 0.2655
# Decision Tree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.33      0.35      0.34      1000
#            1       0.29      0.27      0.28      1000
#            2       0.21      0.23      0.22      1000
#            3       0.20      0.19      0.19      1000
#            4       0.21      0.22      0.21      1000
#            5       0.21      0.21      0.21      1000
#            6       0.28      0.26      0.27      1000
#            7       0.27      0.27      0.27      1000
#            8       0.37      0.38      0.38      1000
#            9       0.29      0.28      0.29      1000
#
#     accuracy                           0.27     10000
#    macro avg       0.27      0.27      0.27     10000
# weighted avg       0.27      0.27      0.27     10000

# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier                        # all the necessary libaries for the assingnment
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import precision_score, recall_score, f1_score

# %%
import tensorflow as tf


(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()             # importing cifar dataset from google collab


print("Training data shape:", x_train.shape)
print("Training labels shape:", y_train.shape)
print("Testing data shape:", x_test.shape)
print("Testing labels shape:", y_test.shape)
# Out:
# Training data shape: (50000, 32, 32, 3)
# Training labels shape: (50000, 1)
# Testing data shape: (10000, 32, 32, 3)
# Testing labels shape: (10000, 1)

# %%
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)


x_train_flat = x_train_flat.astype('float32')                 # converting all the images to pixels
x_test_flat = x_test_flat.astype('float32')

x_train_flat /= 255.0
x_test_flat /= 255.0


y_train = np.squeeze(y_train)
y_test = np.squeeze(y_test)

# %%
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(x_train_flat, y_train)


rf_classifier = RandomForestClassifier(n_estimators=100)
rf_classifier.fit(x_train_flat, y_train)


nb_classifier = GaussianNB()                                                 # defining all the classifiers
nb_classifier.fit(x_train_flat, y_train)


knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(x_train_flat, y_train)
# Out:
# KNeighborsClassifier()

# %%
classifiers = {
    "Decision Tree": dt_classifier,
    "Random Forest": rf_classifier,
    "Naive Bayes": nb_classifier,                          # all the ML models
    "KNN (k=5)": knn_classifier
}

# %%
for clf_name, clf in classifiers.items():
    y_pred = clf.predict(x_test_flat)
    accuracy = clf.score(x_test_flat, y_test)
    precision = precision_score(y_test, y_pred, average='macro')
    recall = recall_score(y_test, y_pred, average='macro')
    f1 = f1_score(y_test, y_pred, average='macro')

    print(clf_name + ":\n")                                        # printing the accuracy , precision , Recall and F1 score
    print("Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("\n")
# Out:
# Decision Tree:
#
# Accuracy: 0.268
# Precision: 0.2680532555345471
# Recall: 0.26799999999999996
# F1 Score: 0.2678800121956922
#
#
# Random Forest:
#
# Accuracy: 0.4686
# Precision: 0.4650342488489178
# Recall: 0.4686
# F1 Score: 0.4652295606768416
#
#
# Naive Bayes:
#
# Accuracy: 0.2976
# Precision: 0.3112140667418117
# Recall: 0.29760000000000003
# F1 Score: 0.2754627838655197
#
#
# KNN (k=5):
#
# Accuracy: 0.3398
# Precision: 0.43042618255284965
# Recall: 0.3398
# F1 Score: 0.3260170986061005

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
for clf_name, clf in classifiers.items():
    y_pred = clf.predict(x_test_flat)
    accuracy = clf.score(x_test_flat, y_test)
    confusion_mat = confusion_matrix(y_test, y_pred)

    print(clf_name + ":\n")
    print("Accuracy:", accuracy)
    print("Confusion Matrix:")                                        # printing the confusion matrix for all the models
    print(confusion_mat)
    print("\n")

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(clf_name + ' Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
# Out:
# Decision Tree:
#
# Accuracy: 0.268
# Confusion Matrix:
# [[337  64 103  41  73  64  40  53 148  77]
#  [ 62 278  78  78  64  53  55  66 106 160]
#  [ 98  53 217  95 139 105 111  84  49  49]
#  [ 69  53 118 172 106 143 116 106  53  64]
#  [ 58  38 159  92 227 118 126  94  48  40]
#  [ 52  54 106 153  87 225 101 102  59  61]
#  [ 37  53 135 122 128  98 278  65  36  48]
#  [ 88  79  89  91  93 100  58 276  48  78]
#  [154 102  44  48  46  47  25  38 392 104]
#  [101 173  52  68  39  54  48  87 100 278]]
# Random Forest:
#
# Accuracy: 0.4686
# Confusion Matrix:
# [[561  41  56  16  29  22  25  21 167  62]
#  [ 29 542  23  40  20  21  36  32  65 192]
#  [ 99  42 334  77 152  64 113  62  26  31]
#  [ 54  44  78 289  67 168 142  64  20  74]
#  [ 45  22 154  45 401  53 149  84  27  20]
#  [ 38  32  71 152  79 414  82  78  22  32]
#  [ 11  32  82  69 124  60 555  26   7  34]
#  [ 53  45  43  60 103  83  55 441  21  96]
#  [ 90  82  22  27  20  33  15  21 606  84]
#  [ 56 155  12  31  21  21  32  46  83 543]]
# Naive Bayes:
#
# Accuracy: 0.2976
# Confusion Matrix:
# [[494  20  39  10  84  34  50   9 200  60]
#  [141 166  24  31  66  72 192  19 121 168]
#  [225  24  83  15 292  48 209  21  54  29]
#  [163  36  54  76 151 129 262  26  34  69]
#  [ 86   8  57  26 417  38 265  22  50  31]
#  [156  17  55  51 167 264 159  36  57  38]
#  [106   2  60  18 228  46 467  15  19  39]
#  [134  24  36  41 228  94 102 131  72 138]
#  [168  41  18  17  56  83  39   8 471  99]
#  [144  67  17  20  48  32 101  23 141 407]]
# KNN (k=5):
#
# Accuracy: 0.3398
# Confusion Matrix:
# [[537   4 117  13  59   7  26   5 225   7]
#  [139 205 110  42 155  36  61  10 217  25]
#  [107   3 452  52 226  34  66   8  49   3]
#  [ 70   8 234 217 193 115  95  17  46   5]
#  [ 64   1 262  35 514  21  41   7  53   2]
#  [ 71   3 227 155 187 220  66  14  51   6]
#  [ 27   2 273  68 314  37 248   2  28   1]
#  [ 93  10 181  50 280  52  53 210  67   4]
#  [141  14  52  38  54  16  14   8 655   8]
#  [153  67  98  68 124  23  46  29 252 140]]

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)  # 20% of 80% validation set

# %%
x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_val_flat = x_val.reshape(x_val.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)


x_train_flat = x_train_flat.astype('float32')
x_val_flat = x_val_flat.astype('float32')
x_test_flat = x_test_flat.astype('float32')


x_train_flat /= 255.0
x_val_flat /= 255.0
x_test_flat /= 255.0

# %%
y_train = np.squeeze(y_train)
y_val = np.squeeze(y_val)
y_test = np.squeeze(y_test)

# %%
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(x_train_flat, y_train)


rf_classifier = RandomForestClassifier(n_estimators=100)
rf_classifier.fit(x_train_flat, y_train)

nb_classifier = GaussianNB()
nb_classifier.fit(x_train_flat, y_train)

knn_classifier = KNeighborsClassifier(n_neighbors=5)
knn_classifier.fit(x_train_flat, y_train)
# Out:
# KNeighborsClassifier()

# %%
classifiers = {
    "Decision Tree": dt_classifier,
    "Random Forest": rf_classifier,
    "Naive Bayes": nb_classifier,
    "KNN (k=5)": knn_classifier
}

# %%
for clf_name, clf in classifiers.items():
    y_pred_val = clf.predict(x_val_flat)
    accuracy = accuracy_score(y_val, y_pred_val)
    precision = precision_score(y_val, y_pred_val, average='macro')
    recall = recall_score(y_val, y_pred_val, average='macro')
    f1 = f1_score(y_val, y_pred_val, average='macro')
    confusion_mat = confusion_matrix(y_val, y_pred_val)

    print(clf_name + ":\n")
    print("Validation Accuracy:", accuracy)
    print("Precision:", precision)
    print("Recall:", recall)
    print("F1 Score:", f1)
    print("Confusion Matrix:")
    print(confusion_mat)
    print("\n")

    plt.figure(figsize=(8, 6))
    sns.heatmap(confusion_mat, annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(clf_name + ' Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
# Out:
# Decision Tree:
#
# Validation Accuracy: 0.2525
# Precision: 0.25408131846340887
# Recall: 0.25273356302308175
# F1 Score: 0.2531192926708978
# Confusion Matrix:
# [[309  84  82  68  67  45  34  68 139  77]
#  [ 79 274  63  58  64  59  61  72  96 153]
#  [ 79  59 188 119 163 113 115 107  51  36]
#  [ 58  63 119 182 105 158 123  99  66  50]
#  [ 61  46 137  98 207  87 124  91  47  35]
#  [ 65  60 109 138 113 210 109 102  55  54]
#  [ 42  52 116 133 131 119 255  70  31  47]
#  [ 71  51  98  86 118  92  86 252  55  85]
#  [154  88  58  66  51  69  38  39 371  83]
#  [104 161  61  89  50  49  58  98  93 277]]
# Random Forest:
#
# Validation Accuracy: 0.4566
# Precision: 0.4530034766929064
# Recall: 0.45695528566774424
# F1 Score: 0.4529787904403352
# Confusion Matrix:
# [[508  64  45  19  30  31  19  30 166  61]
#  [ 35 527  17  40  21  39  38  33  60 169]
#  [ 96  41 308  75 164  75 133  71  36  31]
#  [ 47  53  76 303  81 195 145  52  16  55]
#  [ 63  31 113  43 378  47 121  74  37  26]
#  [ 36  49  91 152  83 378  96  75  25  30]
#  [ 15  42  85  61 113  56 555  32  10  27]
#  [ 44  34  60  57 121  76  59 433  26  84]
#  [113  94  22  39  17  39  17  19 587  70]
#  [ 37 181  10  35  17  36  32  35  68 589]]
# Naive Bayes:
#
# Validation Accuracy: 0.2838
# Precision: 0.2903552952819297
# Recall: 0.285409963713768
# F1 Score: 0.26119568442768293
# Confusion Matrix:
# [[433  38  20  11  92  37  46   9 215  72]
#  [123 142  19  50  71  82 172  21 119 180]
#  [207  29  81  17 310  41 215  29  60  41]
#  [156  40  60  76 144 160 277  26  30  54]
#  [ 93   5  39  22 408  34 221  23  53  35]
#  [144  30  64  46 177 255 188  35  44  32]
#  [101  11  41  22 223  47 479  17  20  35]
#  [133  27  35  40 262  86 112 115  56 128]
#  [195  42  17  21  51  87  59  12 442  91]
#  [133  84  16  21  55  30 106  25 163 407]]
# KNN (k=5):
#
# Validation Accuracy: 0.3325
# Precision: 0.42660943408366936
# Recall: 0.33427759981985805
# F1 Score: 0.3186776412486527
# Confusion Matrix:
# [[525   7  83  14  67  11  26  11 220   9]
#  [140 199  94  35 183  28  72  10 192  26]
#  [138   5 425  47 256  42  52   9  56   0]
#  [ 86   9 250 222 195 113  98   8  39   3]
#  [ 96   3 213  41 470  14  32   9  55   0]
#  [ 75   6 242 164 183 223  77   5  39   1]
#  [ 39   7 261  60 294  41 260   7  26   1]
#  [ 96   3 181  63 289  39  56 192  62  13]
#  [148  12  46  35  50  20  15   3 679   9]
#  [164  58 111  54 135  34  48  24 282 130]]

# %%
import numpy as np
from sklearn.model_selection import cross_val_score, StratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()


x_train_flat = x_train.reshape(x_train.shape[0], -1)
x_test_flat = x_test.reshape(x_test.shape[0], -1)


x_train_flat = x_train_flat.astype('float32')
x_test_flat = x_test_flat.astype('float32')


x_train_flat /= 255.0
x_test_flat /= 255.0


y_train = np.squeeze(y_train)
y_test = np.squeeze(y_test)

# %%
classifiers = {
    "Decision Tree": DecisionTreeClassifier(),
    "Random Forest": RandomForestClassifier(n_estimators=100),
    "Naive Bayes": GaussianNB(),
    "KNN (k=5)": KNeighborsClassifier(n_neighbors=5)
}

# %%
for clf_name, clf in classifiers.items():
    skf = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1s = []                                                                             # performing 3 fold cross validation on all the machine learning models
    confusion_matrices = []

    for train_index, val_index in skf.split(x_train_flat, y_train):
        x_train_cv, x_val_cv = x_train_flat[train_index], x_train_flat[val_index]
        y_train_cv, y_val_cv = y_train[train_index], y_train[val_index]

        clf.fit(x_train_cv, y_train_cv)
        y_pred_cv = clf.predict(x_val_cv)

        accuracies.append(accuracy_score(y_val_cv, y_pred_cv))
        precisions.append(precision_score(y_val_cv, y_pred_cv, average='macro'))
        recalls.append(recall_score(y_val_cv, y_pred_cv, average='macro'))
        f1s.append(f1_score(y_val_cv, y_pred_cv, average='macro'))
        confusion_matrices.append(confusion_matrix(y_val_cv, y_pred_cv))

    print(clf_name + " Cross-Validation Results:\n")
    print("Average Accuracy:", np.mean(accuracies))
    print("Average Precision:", np.mean(precisions))
    print("Average Recall:", np.mean(recalls))
    print("Average F1 Score:", np.mean(f1s))
    print("\n")

    avg_confusion_mat = np.mean(confusion_matrices, axis=0)
    plt.figure(figsize=(8, 6))
    sns.heatmap(avg_confusion_mat.astype(int), annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(clf_name + ' Average Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
# Out:
# Decision Tree Cross-Validation Results:
#
# Average Accuracy: 0.26154002540974025
# Average Precision: 0.262233155717996
# Average Recall: 0.2615406330498607
# Average F1 Score: 0.2617335534327771
# Random Forest Cross-Validation Results:
#
# Average Accuracy: 0.4513199871607992
# Average Precision: 0.4481255830721608
# Average Recall: 0.4513209482953349
# Average F1 Score: 0.4479426121281637
# Naive Bayes Cross-Validation Results:
#
# Average Accuracy: 0.28438001622782855
# Average Precision: 0.2952183617283109
# Average Recall: 0.28438141903432035
# Average F1 Score: 0.263002118273418
# KNN (k=5) Cross-Validation Results:
#
# Average Accuracy: 0.3254800114606132
# Average Precision: 0.41694301642700715
# Average Recall: 0.3254793579099306
# Average F1 Score: 0.3104843457043133

# %%
for clf_name, clf in classifiers.items():
    skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1s = []
    confusion_matrices = []
                                                                                            # performing 5 fold analysis cross validation on all the ML models
    for train_index, val_index in skf.split(x_train_flat, y_train):
        x_train_cv, x_val_cv = x_train_flat[train_index], x_train_flat[val_index]
        y_train_cv, y_val_cv = y_train[train_index], y_train[val_index]

        clf.fit(x_train_cv, y_train_cv)
        y_pred_cv = clf.predict(x_val_cv)

        accuracies.append(accuracy_score(y_val_cv, y_pred_cv))
        precisions.append(precision_score(y_val_cv, y_pred_cv, average='macro'))
        recalls.append(recall_score(y_val_cv, y_pred_cv, average='macro'))
        f1s.append(f1_score(y_val_cv, y_pred_cv, average='macro'))
        confusion_matrices.append(confusion_matrix(y_val_cv, y_pred_cv))

    print(clf_name + " Cross-Validation Results:\n")
    print("Average Accuracy:", np.mean(accuracies))
    print("Average Precision:", np.mean(precisions))
    print("Average Recall:", np.mean(recalls))
    print("Average F1 Score:", np.mean(f1s))
    print("\n")

    avg_confusion_mat = np.mean(confusion_matrices, axis=0)
    plt.figure(figsize=(8, 6))
    sns.heatmap(avg_confusion_mat.astype(int), annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(clf_name + ' Average Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
# Out:
# Decision Tree Cross-Validation Results:
#
# Average Accuracy: 0.26174
# Average Precision: 0.26259513026265013
# Average Recall: 0.26174
# Average F1 Score: 0.26203721483055303
# Random Forest Cross-Validation Results:
#
# Average Accuracy: 0.45702
# Average Precision: 0.4536473723384569
# Average Recall: 0.45702
# Average F1 Score: 0.4536145039435605
# Naive Bayes Cross-Validation Results:
#
# Average Accuracy: 0.28480000000000005
# Average Precision: 0.2955955084470586
# Average Recall: 0.28480000000000005
# Average F1 Score: 0.2633039374765517
# KNN (k=5) Cross-Validation Results:
#
# Average Accuracy: 0.3327
# Average Precision: 0.42636486152381925
# Average Recall: 0.33270000000000005
# Average F1 Score: 0.31852543093801977

# %%
for clf_name, clf in classifiers.items():
    skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
    accuracies = []
    precisions = []
    recalls = []
    f1s = []                                                                             # performing 10 fold cross validation on all the ML models
    confusion_matrices = []

    for train_index, val_index in skf.split(x_train_flat, y_train):
        x_train_cv, x_val_cv = x_train_flat[train_index], x_train_flat[val_index]
        y_train_cv, y_val_cv = y_train[train_index], y_train[val_index]

        clf.fit(x_train_cv, y_train_cv)
        y_pred_cv = clf.predict(x_val_cv)

        accuracies.append(accuracy_score(y_val_cv, y_pred_cv))
        precisions.append(precision_score(y_val_cv, y_pred_cv, average='macro'))
        recalls.append(recall_score(y_val_cv, y_pred_cv, average='macro'))
        f1s.append(f1_score(y_val_cv, y_pred_cv, average='macro'))
        confusion_matrices.append(confusion_matrix(y_val_cv, y_pred_cv))

    print(clf_name + " Cross-Validation Results:\n")
    print("Average Accuracy:", np.mean(accuracies))
    print("Average Precision:", np.mean(precisions))
    print("Average Recall:", np.mean(recalls))
    print("Average F1 Score:", np.mean(f1s))
    print("\n")

    avg_confusion_mat = np.mean(confusion_matrices, axis=0)
    plt.figure(figsize=(8, 6))
    sns.heatmap(avg_confusion_mat.astype(int), annot=True, fmt='d', cmap='Blues', cbar=False)
    plt.title(clf_name + ' Average Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
# Out:
# Decision Tree Cross-Validation Results:
#
# Average Accuracy: 0.26446000000000003
# Average Precision: 0.2653625834257762
# Average Recall: 0.26446000000000003
# Average F1 Score: 0.2647190751436134
# Random Forest Cross-Validation Results:
#
# Average Accuracy: 0.4631200000000001
# Average Precision: 0.45979465619484
# Average Recall: 0.4631200000000001
# Average F1 Score: 0.4595480803811493
# Naive Bayes Cross-Validation Results:
#
# Average Accuracy: 0.28447999999999996
# Average Precision: 0.294711544502295
# Average Recall: 0.28448
# Average F1 Score: 0.2628604439425539
# KNN (k=5) Cross-Validation Results:
#
# Average Accuracy: 0.33602
# Average Precision: 0.42893888417254233
# Average Recall: 0.33602
# Average F1 Score: 0.3223506850986591
